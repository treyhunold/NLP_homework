# %%
import os
import pandas as pd
# %matplotlib inline

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Read your api key environment variable
api_key = os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
btc_headlines = newsapi.get_everything(
    q="bitcoin",
    language="en",
    sort_by="relevancy"
)

# %%
btc_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 3474,
#  'articles': [{'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Brian Barrett',
#    'title': "The 'Robo Revenge' App Makes It Easy to Sue Robocallers",
#    'description': "Mac malware, a Bitcoin mixer, and more of the week's top security news.",
#    'url': 'https://www.wired.com/story/robo-revenge-apple-malware-security-news/',
#    'urlToImage': 'https://media.wired.com/photos/5e471046e7120600088b2022/191:100/w_1280,c_limit/Security_robbocalls-84289419.jpg',
#    'publishedAt': '2020-02-15T14:00:00Z',
#    'content': "Just when you thought the catastrophic Equifax breach was entirely in the rearview, the Department of Justice this week charged four Chinese military hackers with the theft. That's 147.9 million people's Social Security numbers and other personal information … [+4002 chars]"},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Stan Schroeder',
#    'title': "HTC's Exodus 5G router can be a Bitcoin node",
#    'description': 'After launching two cryptocurrency-oriented smartphones, the HTC Exodus 1 and the Exodus 1s, the company is expanding the lineup with an entirely new device: a 5G router that can function as a full Bitcoin node. Called the HTC Exodus 5G hub, the Android-based…',
#    'url': 'https://mashable.com/article/htc-exodus-5g-hub/',
#    'urlToImage': 'https://mondrian.mashable.com/2020%252F03%252F04%252F22%252Fe8359029a8744acb93599edc973a0d95.7928e.jpg%252F1200x630.jpg?signature=b9tTdqwOKyi9aHqSL-KIA6J_RwY=',
#    'publishedAt': '2020-03-04T13:00:00Z',
#    'content': 'After launching two cryptocurrency-oriented smartphones, the HTC Exodus 1 and the Exodus 1s, the company is expanding the lineup with an entirely new device: a 5G router that can function as a full Bitcoin node.\xa0\r\nCalled the HTC Exodus 5G hub, the Android-bas… [+2230 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Romain Dillet',
#    'title': 'DeFi aims to bridge the gap between blockchains and financial services',
#    'description': 'If you’ve been following cryptocurrency news for the past few months, there’s one word that keeps coming back — DeFi, also known as decentralized finance. As the name suggests, DeFi aims to bridge the gap between decentralized blockchains and financial servic…',
#    'url': 'http://techcrunch.com/2020/02/20/defi-aims-to-bridge-the-gap-between-blockchains-and-financial-services/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/02/dmitry-demidko-z4VuRg-ZOEg-unsplash.jpg?w=600',
#    'publishedAt': '2020-02-20T19:18:20Z',
#    'content': 'If youve been following cryptocurrency news for the past few months, theres one word that keeps coming back DeFi, also known as decentralized finance. As the name suggests, DeFi aims to bridge the gap between decentralized blockchains and financial services.\r… [+983 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Manish Singh',
#    'title': 'India lifts ban on cryptocurrency trading',
#    'description': 'India’s Supreme Court on Wednesday struck down central bank’s two-year-old ban on cryptocurrency trading in the country in what many said was a “historic” verdict. The Reserve Bank of India had imposed a ban on cryptocurrency trading in April 2018 that barred…',
#    'url': 'http://techcrunch.com/2020/03/03/india-lifts-ban-on-cryptocurrency-trading/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/03/GettyImages-1174941001.jpg?w=600',
#    'publishedAt': '2020-03-04T06:19:08Z',
#    'content': 'Indias Supreme Court on Wednesday overturned\xa0central banks two-year-old ban on cryptocurrency trading in the country in what many said was a historic verdict.\r\nThe Reserve Bank of India had imposed a ban on cryptocurrency trading in April 2018 that barred ban… [+1336 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jay Peters',
#    'title': 'IRS backtracks on whether video game currencies are taxable',
#    'description': 'The IRS quietly removed a provision on its website that said you might have to report transactions involving video game currencies on your tax returns. The IRS’ chief counsel said mentioning video games was a mistake.',
#    'url': 'https://www.theverge.com/2020/2/13/21137045/irs-provision-virtual-currency-tax-returns-fortnite-v-bucks',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/SLLGigPOOcRWZOVySx01jGGI2sI=/0x109:1520x905/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/19719342/vbucks.0__1_.png',
#    'publishedAt': '2020-02-14T04:49:34Z',
#    'content': 'But its still unclear if you need to report them\r\nImage: Epic Games\r\nOn Wednesday, the IRS quietly changed a provision on its website that said transactions of virtual currency like Fortnites V-bucks were taxable and may have to be reported on tax returns, as… [+2532 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Dutch letter-bomb blackmail campaign targets companies',
#    'description': 'Police are investigating a spate of letter-bomb attacks on companies across the Netherlands.',
#    'url': 'https://www.bbc.co.uk/news/world-europe-51488862',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/BD0E/production/_110889384_bombrief.jpg',
#    'publishedAt': '2020-02-13T16:31:48Z',
#    'content': 'Image copyrightDutch policeImage caption\r\n Dutch police have warned companies to look out for padded envelopes with two stamps\r\nPolice are investigating a spate of letter-bomb attacks on companies across the Netherlands.\r\nFour letter bombs have been found in … [+2882 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'The Countdown To Bitcoin Halving 2020 Begins',
#    'description': 'Ali Raza from InsideBitcoins discusses the expected Bitcoin Halving in May 2020, and the impact it will have on the market valuation. From the report: The next Bitcoin Halving will take place on May 20th 2020. It will be the third time, that the block reward …',
#    'url': 'https://news.slashdot.org/story/20/02/17/231219/the-countdown-to-bitcoin-halving-2020-begins',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2020-02-18T00:50:00Z',
#    'content': 'The next Bitcoin Halving will take place on May 20th 2020. It will be the third time, that the block reward of the most known blockchain will be halved. As a consequence, miners will earn 50 percent less BTC for every generated block. Experts are expecting, t… [+922 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Virgin Galactic chair says you should have 1% of your assets in Bitcoin’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Machiavelli used to say: Money makes the w…',
#    'url': 'https://thenextweb.com/hardfork/2020/03/02/satoshi-nakaboto-virgin-galactic-chair-says-you-should-have-1-of-your-assets-in-bitcoin/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-03-02T09:56:50Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Machiavelli used to say: Money makes t… [+2973 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘New York power plant makes $50K a day mining Bitcoin’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Stephen Hawking used to say: Let’s get it!…',
#    'url': 'https://thenextweb.com/hardfork/2020/03/06/satoshi-nakaboto-new-york-power-plant-makes-50k-a-day-mining-bitcoin/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-03-06T10:36:53Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Stephen Hawking used to say: Lets get … [+3088 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Germany deems Bitcoin a financial instrument’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Rousseau used to say: Success is just a pr…',
#    'url': 'https://thenextweb.com/hardfork/2020/03/04/satoshi-nakaboto-germany-deems-bitcoin-a-financial-instrument/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-03-04T11:34:31Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Rousseau used to say: Success is just … [+2892 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin hits 3-month low as it dips below $8,000’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Hegel used to say: Whip it, whip it, whip …',
#    'url': 'https://thenextweb.com/hardfork/2020/03/10/satoshi-nakaboto-bitcoin-hits-3-month-low-as-it-dips-below-8000/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-03-10T10:08:22Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Hegel used to say: Whip it, whip it, w… [+2889 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Danny Crichton',
#    'title': 'South Korea passes one of the world’s first comprehensive cryptocurrency laws',
#    'description': 'The South Korean National Assembly passed new legislation today that will provide a framework for the regulation and legalization of cryptocurrencies and crypto exchanges. In a unanimous vote during a special session of the legislature convened amidst the cou…',
#    'url': 'http://techcrunch.com/2020/03/05/south-korea-passes-one-of-the-worlds-first-comprehensive-cryptocurrency-laws/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/03/8496230391_58e1c0f1ab_o.jpg?w=648',
#    'publishedAt': '2020-03-05T16:07:24Z',
#    'content': 'The South Korean National Assembly passed new legislation today that will provide a framework for the regulation and legalization of cryptocurrencies and crypto exchanges.\r\nIn a unanimous vote during a special session of the legislature convened amidst the co… [+2878 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin hash rate hits all-time high’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Marie Curie used to say: Talk to a strange…',
#    'url': 'https://thenextweb.com/hardfork/2020/03/03/satoshi-nakaboto-bitcoin-hash-rate-hits-all-time-high/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-03-03T10:14:02Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Marie Curie used to say: Talk to a str… [+2973 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bank of England says Bitcoin holders must be prepared to lose it all’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Machiavelli used to say: Yolo! Bitcoin pri…',
#    'url': 'http://feedproxy.google.com/~r/TheNextWeb/~3/7_DiAOfe-ag/',
#    'urlToImage': None,
#    'publishedAt': '2020-03-05T11:10:18Z',
#    'content': None},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin plunges alongside global markets’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Stephen Hawking used to say: Fight the pow…',
#    'url': 'https://thenextweb.com/hardfork/2020/03/09/satoshi-nakaboto-bitcoin-plunges-alongside-global-markets/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-03-09T10:09:40Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Stephen Hawking used to say: Fight the… [+3054 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin dips just enough to fill gap in futures market’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Baudriallard used to say: Success is just …',
#    'url': 'https://thenextweb.com/hardfork/2020/02/11/satoshi-nakaboto-bitcoin-dips-just-enough-to-fill-gap-in-futures-market/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-02-11T10:04:54Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Baudriallard used to say: Success is j… [+2536 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Visa allows Coinbase to issue Bitcoin debit cards‘',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Plato used to say: Success is just a produ…',
#    'url': 'https://thenextweb.com/hardfork/2020/02/20/satoshi-nakaboto-visa-allows-coinbase-to-issue-bitcoin-debit-cards/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-02-20T10:50:11Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Plato used to say: Success is just a p… [+2565 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘TV host Max Keiser says Bitcoin will go to $400k, not $100k’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Baudriallard used to say: Let’s whip up a …',
#    'url': 'https://thenextweb.com/hardfork/2020/02/18/satoshi-nakaboto-tv-host-max-keiser-says-bitcoin-will-go-to-400k-not-100k/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-02-18T10:11:28Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Baudriallard used to say: Lets whip up… [+2613 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Steven Seagal to pay $330K settlement for promoting a Bitcoin scam’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Hannah Arendt used to say: Crack open this…',
#    'url': 'https://thenextweb.com/hardfork/2020/02/28/satoshi-nakaboto-steven-seagal-to-pay-330k-settlement-for-promoting-a-bitcoin-scam/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-02-28T11:10:12Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Hannah Arendt used to say: Crack open … [+2601 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Aww yeah, Bitcoin is back above $10K’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Nightingale used to say: I got the horses …',
#    'url': 'https://thenextweb.com/hardfork/2020/02/19/satoshi-nakaboto-aww-yeah-bitcoin-is-back-above-10k/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-02-19T11:00:13Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Nightingale used to say: I got the hor… [+2963 chars]'}]}

# %%
# Fetch the Ethereum news articles
eth_headlines = newsapi.get_everything(
    q="ethereum",
    language="en",
    sort_by="relevancy"
)

# %%
eth_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 864,
#  'articles': [{'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Greg Kumparak',
#    'title': 'Horizon raises another $5M to put virtual items on the blockchain and launch its first game',
#    'description': 'If a player picks up an item in an online video game, who owns that item? The player, or the company that made the game? In most cases, the answer is probably closer to the latter. The item may be in the player’s digital inventory – but the company can take i…',
#    'url': 'http://techcrunch.com/2020/03/06/horizon-raises-another-5m-to-put-virtual-items-on-the-blockchain/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/03/skyweaver.png?w=756',
#    'publishedAt': '2020-03-06T17:01:15Z',
#    'content': 'If a player picks up an item in an online video game, who owns that item? The player, or the company that made the game?\r\nIn most cases, the answer is probably closer to the latter. The item may be in the players digital inventory – but the company can take i… [+2713 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Romain Dillet',
#    'title': 'DeFi aims to bridge the gap between blockchains and financial services',
#    'description': 'If you’ve been following cryptocurrency news for the past few months, there’s one word that keeps coming back — DeFi, also known as decentralized finance. As the name suggests, DeFi aims to bridge the gap between decentralized blockchains and financial servic…',
#    'url': 'http://techcrunch.com/2020/02/20/defi-aims-to-bridge-the-gap-between-blockchains-and-financial-services/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/02/dmitry-demidko-z4VuRg-ZOEg-unsplash.jpg?w=600',
#    'publishedAt': '2020-02-20T19:18:20Z',
#    'content': 'If youve been following cryptocurrency news for the past few months, theres one word that keeps coming back DeFi, also known as decentralized finance. As the name suggests, DeFi aims to bridge the gap between decentralized blockchains and financial services.\r… [+983 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Jack Morse',
#    'title': "Not above the law: Steven Seagal's shady crypto past under siege by SEC",
#    'description': 'When it comes to celebrities shilling shady initial coin offerings for money, the Securities and Exchange Commission is out for justice. Actor Steven Seagal found himself on deadly ground on Thursday following an SEC charge that, back in 2018, he failed to di…',
#    'url': 'https://mashable.com/article/steven-seagal-sec-fines-cryptocurrency/',
#    'urlToImage': 'https://mondrian.mashable.com/2020%252F02%252F27%252F62%252F33bc2c511f854ffd9762a56b0d23dd82.ac10e.png%252F1200x630.png?signature=ewfjo8b6u9NF5rRa523LyUklJ0I=',
#    'publishedAt': '2020-02-27T19:33:58Z',
#    'content': 'When it comes to celebrities shilling shady initial coin offerings for money, the Securities and Exchange Commission is out for justice.\xa0\r\nActor Steven Seagal found himself on deadly ground on Thursday following an SEC charge that, back in 2018, he failed to … [+2035 chars]'},
#   {'source': {'id': None, 'name': 'Venturebeat.com'},
#    'author': 'Dean Takahashi',
#    'title': 'Skale Network to launch cryptocurrency tokens that withstand regulatory scrutiny',
#    'description': 'Skale Network wants to encourage wide adoption of its blockchain-based technology and is taking steps to help its tokens pass regulatory scrutiny.',
#    'url': 'https://venturebeat.com/2020/02/11/skale-network-to-launch-cryptocurrency-tokens-that-withstand-regulatory-scrutiny/',
#    'urlToImage': 'https://venturebeat.com/wp-content/uploads/2020/02/SKALE_ExplainerVideo_1.jpg?w=1200&strip=all',
#    'publishedAt': '2020-02-11T16:01:28Z',
#    'content': 'Skale Network is taking steps to help its cryptocurrency tokens stand up to regulatory scrutiny in an effort to encourage wide adoption for its blockchain-based technology.\r\nSkale Network, overseen by the N.O.D.E. Foundation, will be the first project to laun… [+2511 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Danny Crichton',
#    'title': 'South Korea passes one of the world’s first comprehensive cryptocurrency laws',
#    'description': 'The South Korean National Assembly passed new legislation today that will provide a framework for the regulation and legalization of cryptocurrencies and crypto exchanges. In a unanimous vote during a special session of the legislature convened amidst the cou…',
#    'url': 'http://techcrunch.com/2020/03/05/south-korea-passes-one-of-the-worlds-first-comprehensive-cryptocurrency-laws/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/03/8496230391_58e1c0f1ab_o.jpg?w=648',
#    'publishedAt': '2020-03-05T16:07:24Z',
#    'content': 'The South Korean National Assembly passed new legislation today that will provide a framework for the regulation and legalization of cryptocurrencies and crypto exchanges.\r\nIn a unanimous vote during a special session of the legislature convened amidst the co… [+2878 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Mike Butcher',
#    'title': 'Tim Draper puts $1M into the Aragon blockchain project to create digital courts',
#    'description': 'In the murky world of crypto and blockchain, taking disputes to a traditional court would either land both the plaintiff and the defendant in jail or confuse the court to the point of total befuddlement. You can just imagine the scenario: “What is a DAO?” “It…',
#    'url': 'http://techcrunch.com/2020/02/19/tim-draper-puts-1m-into-the-aragon-blockchain-project-to-create-digital-courts/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/01/GettyImages-1169335675.jpg?w=764',
#    'publishedAt': '2020-02-19T17:10:29Z',
#    'content': 'In the murky world of crypto and blockchain, taking disputes to a traditional court would either land both the plaintiff and the defendant in jail or confuse the court to the point of total befuddlement. You can just imagine the scenario:\r\nWhat is a DAO?\r\nIts… [+3338 chars]'},
#   {'source': {'id': None, 'name': 'Readwrite.com'},
#    'author': 'Kyle Ellicott',
#    'title': 'Your Blockchain & DApps Weekly Round Up – February 21, 2020',
#    'description': 'Hacker Makes $1M Exploiting DeFi / Steemit Shifting to Tron / JPMorgan Quorum & ConsenSys Talk Merger / China Using Blockchain Against Coronavirus To say a lot happened this past week would be is an understatement. It seems that 2020 has no intention of slowi…',
#    'url': 'https://readwrite.com/2020/02/21/blockchain-and-dapps-weekly-round-up-2-21-2020/',
#    'urlToImage': 'https://images.readwrite.com/wp-content/uploads/2020/02/valeriia-bugaiova-Kd3BSvLgUIo-unsplash.jpg',
#    'publishedAt': '2020-02-21T20:23:02Z',
#    'content': 'To say a lot happened this past week would be is an understatement. It seems that 2020 has no intention of slowing down based on all the recent happenings of the blockchain, DApps &amp; DLT landscapes. Lets take a deep breath and calmly try to go through it a… [+5316 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Gregory Barber',
#    'title': 'This Social Network Wants to Pay You (in Crypto) to Do Good',
#    'description': 'Block.one raised $4 billion in 2018 by promising to build a decentralized, blockchain-based platform. Now its social network wants to encourage quality posts.',
#    'url': 'https://www.wired.com/story/social-network-wants-pay-crypto-do-good/',
#    'urlToImage': 'https://media.wired.com/photos/5e45e2fe0334170008035103/191:100/w_1280,c_limit/EOS-Voice_919436000.jpg',
#    'publishedAt': '2020-02-14T13:00:00Z',
#    'content': 'Last June, at a swanky, strobe-lit event in Washington, DC, Brendan Blumer, the 33-year-old CEO of a blockchain company called Block.one, unveiled a new product with Steve Jobs-like theatrics: a social network called Voice. A year earlier, Blumers company had… [+3666 chars]'},
#   {'source': {'id': None, 'name': 'Avc.com'},
#    'author': 'Fred Wilson',
#    'title': 'USDC',
#    'description': 'I just bought some US Dollars today. I do that many days. But the dollars I bought today are crypto assets, like Bitcoin and Ethereum. These US Dollar assets are called USDC and they are issued by an industry consortium called Centre, led by Circle and our po…',
#    'url': 'https://avc.com/2020/02/usdc/',
#    'urlToImage': None,
#    'publishedAt': '2020-02-11T12:01:17Z',
#    'content': 'I just bought some US Dollars today. I do that many days. But the dollars I bought today are crypto assets, like Bitcoin and Ethereum. These US Dollar assets are called USDC and they are issued by an industry consortium called Centre, led by Circle and our po… [+2120 chars]'},
#   {'source': {'id': None, 'name': 'Sigarch.org'},
#    'author': None,
#    'title': 'The Changing World of Storage',
#    'description': 'The world of storage is changing rapidly. We have exciting new technologies such as Intel DC Persistent Memory, along with new applications such as machine learning and blockchain which place new r…',
#    'url': 'https://www.sigarch.org/the-changing-world-of-storage/',
#    'urlToImage': 'https://www.sigarch.org/wp-content/uploads/2020/03/AdobeStock_222912660-scaled.jpeg',
#    'publishedAt': '2020-03-02T20:07:11Z',
#    'content': 'The world of storage is changing rapidly. We have exciting new technologies such as Intel DC Persistent Memory, along with new applications such as machine learning and blockchain which place new requirements on storage systems. Researchers are working on new… [+7451 chars]'},
#   {'source': {'id': None, 'name': 'Terminal.co'},
#    'author': None,
#    'title': 'Terminal V2',
#    'description': 'The easiest way to build, deploy, and host websites & apps on IPFS',
#    'url': 'https://blog.terminal.co/introducing-terminal-v2/',
#    'urlToImage': None,
#    'publishedAt': '2020-02-13T10:23:22Z',
#    'content': 'Today, were excited to launch a new version of Terminal - the easiest way to build, deploy, and host websites &amp; apps on IPFS. From local development to global deployment, Terminal provides one seamless workflow with everything you need to build fast, mode… [+5610 chars]'},
#   {'source': {'id': None, 'name': 'Pcmag.com'},
#    'author': 'Kathy Yakal',
#    'title': 'Cryptocurrency and Taxes: What You Need to Know',
#    'description': "This year, for the first time, federal tax forms ask about your bitcoin and other cryptocurrency activities. Here's a look at the implications for your income taxes.",
#    'url': 'https://www.pcmag.com/news/cryptocurrency-and-taxes-what-you-need-to-know',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/20200226162654-cryptocurrency.jpeg',
#    'publishedAt': '2020-02-26T16:29:09Z',
#    'content': 'February\r\n26, 2020\r\n7 min read\r\nThis story originally appeared on PC MagCryptocurrency is digital currency, or a “digital representation of value,” as the IRS puts it. You can’t see it, hold it in your hand, or put it in your wallet. It’s been in use for over… [+7653 chars]'},
#   {'source': {'id': None, 'name': 'Codemotion.com'},
#    'author': 'Cate Lawrence',
#    'title': 'Change to the most in-demand job of 2020: Blockchain Developer',
#    'description': 'We take a look at how to why to join the most in demand skill of 2020: blockchain developer.',
#    'url': 'https://www.codemotion.com/magazine/dev-hub/blockchain-dev/be-in-demand-how-and-why-to-become-a-blockchain-developer/',
#    'urlToImage': 'https://www.codemotion.com/magazine/wp-content/uploads/2020/02/blockchain-3019120_1280.png',
#    'publishedAt': '2020-02-10T12:19:34Z',
#    'content': 'Last month, LinkedIn published a list of the most in-demand skills for the new year, with blockchain leading the top-ten list. In 2019, blockchain didnt make the list at all. Blockchain also ranked as the most in-demand skills in the United States, the United… [+5960 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘TV host Max Keiser says Bitcoin will go to $400k, not $100k’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Baudriallard used to say: Let’s whip up a …',
#    'url': 'https://thenextweb.com/hardfork/2020/02/18/satoshi-nakaboto-tv-host-max-keiser-says-bitcoin-will-go-to-400k-not-100k/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-02-18T10:11:28Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Baudriallard used to say: Lets whip up… [+2613 chars]'},
#   {'source': {'id': None, 'name': 'Techmeme.com'},
#    'author': None,
#    'title': 'Review of Decentraland, a virtual world on Ethereum blockchain, which launched this week and allows users to trade unique digital Decentraland assets in crypto (Michael McSweeney/The Block)',
#    'description': 'Michael McSweeney / The Block : Review of Decentraland, a virtual world on Ethereum blockchain, which launched this week and allows users to trade unique digital Decentraland assets in crypto — When I first started poking around Decentraland on its launch day…',
#    'url': 'https://www.techmeme.com/200224/p11',
#    'urlToImage': 'https://www.tbstat.com/wp/uploads/2020/02/Bird.jpg',
#    'publishedAt': '2020-02-24T15:35:01Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Techmeme.com'},
#    'author': None,
#    'title': 'Crypto lending and borrowing service BlockFi raises $30M Series B led by Valar Ventures, bringing its total raised to over $100M (Robert Stevens/Decrypt)',
#    'description': "Robert Stevens / Decrypt : Crypto lending and borrowing service BlockFi raises $30M Series B led by Valar Ventures, bringing its total raised to over $100M — The latest funding round pushed BlockFi's total funding to over $100 million. — Ethereum — Crypto len…",
#    'url': 'https://www.techmeme.com/200213/p8',
#    'urlToImage': 'https://cdn.decrypt.co/wp-content/uploads/2020/02/shutterstock_1565452071-900x470.jpg',
#    'publishedAt': '2020-02-13T15:15:16Z',
#    'content': 'About This Page\r\nThis is a Techmeme archive page.\r\nIt shows how the site appeared at 10:15\xa0AM\xa0ET, February\xa013,\xa02020.\r\nThe most current version of the site as always is available at our home page.\r\nTo view an earlier snapshot click here\r\nand then modify the da… [+12 chars]'},
#   {'source': {'id': None, 'name': 'Forbes.com'},
#    'author': 'Michael del Castillo, Forbes Staff, Michael del Castillo, Forbes Staff https://www.forbes.com/sites/michaeldelcastillo/',
#    'title': 'Morningstar Rates First Ethereum Security In $39 Million Fatburger Deal',
#    'description': 'Ratings giant DBRS Morningstar rated its first security using the ethereum blockchain, a $40 million deal that paves the way to a $113 trillion market.',
#    'url': 'https://www.forbes.com/sites/michaeldelcastillo/2020/03/08/morningstar-rates-first-ethereum-debt-security-in-40-million-fatburger-deal/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F162982755%2F0x0.jpg',
#    'publishedAt': '2020-03-08T13:00:00Z',
#    'content': "The parent company of the Fatburger franchise is planning on buying a new chain of restaurants, and ... [+] they're raising the capital using the ethereum blockchain.\r\nRizwan Tabassum/ AFP via Getty Images\r\nFatburger just got a little more juicy thanks to a h… [+12437 chars]"},
#   {'source': {'id': None, 'name': 'Forbes.com'},
#    'author': 'Biser Dimitrov, Contributor, Biser Dimitrov, Contributor https://www.forbes.com/sites/biserdimitrov/',
#    'title': 'Microsoft, EY And ConsenSys To Make The Public Ethereum Blockchain Safe For Enterprises',
#    'description': 'Baseline Protocol is a new initiative from Microsoft, EY and ConsenSys aimed at providing safe and effective way for enterprises to interact with the public Ethereum blockchain.',
#    'url': 'https://www.forbes.com/sites/biserdimitrov/2020/03/04/microsoft-ey-and-consensys-to-make-the-public-ethereum-blockchain-safe-for-enterprises/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F1176801138%2F0x0.jpg',
#    'publishedAt': '2020-03-04T15:00:00Z',
#    'content': 'Joseph Lubin, Co-Founder, Ethereum; Founder, Consensys\r\nGetty Images for Concordia Summit\r\nBlockchain, as a new technology, has faced fair critique in the last few years that it is a solution looking for a problem. This was mostly echoed by the predominant us… [+4339 chars]'},
#   {'source': {'id': None, 'name': 'Forbes.com'},
#    'author': 'Billy Bambrough, Contributor, Billy Bambrough, Contributor https://www.forbes.com/sites/billybambrough/',
#    'title': 'Exclusive: Leak Reveals Surprising Reason Major Bitcoin Exchange Luno Is Adding Ripple’s XRP',
#    'description': "London-based bitcoin and cryptocurrency exchange Luno is adding support for Ripple's XRP, the third-largest cryptocurrency by value behind bitcoin and ethereum. Here's why...",
#    'url': 'https://www.forbes.com/sites/billybambrough/2020/02/28/exclusive-leak-reveals-surprising-reason-major-bitcoin-exchange-luno-is-adding-ripples-xrp/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/600x315/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5e566f20d378190007f454d5%2F960x0.jpg',
#    'publishedAt': '2020-02-28T11:00:32Z',
#    'content': "London-based bitcoin and cryptocurrency exchange Luno is adding support for Ripple's XRP, the third-largest cryptocurrency by value behind bitcoin and ethereum.The addition of XRP to Luno's supported cryptocurrencies, which currently includes just bitcoin, et… [+5953 chars]"},
#   {'source': {'id': None, 'name': 'Coindesk.com'},
#    'author': 'Brady Dale',
#    'title': '$100K in Early Prizes Looks to Lure the NFT-Curious to Decentraland',
#    'description': 'Decentraland opened for gameplay today, delivering on promises of bringing an NFT-based "metaverse" to ethereum.',
#    'url': 'https://www.coindesk.com/100k-in-early-prizes-looks-to-lure-the-nft-curious-to-decentraland',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/02/VegasPlaza_06-1-e1582218747436.png',
#    'publishedAt': '2020-02-20T17:11:22Z',
#    'content': 'Decentraland opened for gameplay on Thursday and anyone who thinks they might like it is better off playing now rather than later, because free stuff.\r\nFor regular gamers, Decentraland may be a new kind of experience, what they call a "metaverse" where differ… [+7218 chars]'}]}

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sentiments = []

for article in btc_headlines["articles"]:
    try:
        sentiment = analyzer.polarity_scores(article["content"])
      
        btc_sentiments.append({
            "text": article["content"],
            "Compound": sentiment["compound"],
            "Positive": sentiment["pos"],
            "Negative": sentiment["neg"],
            "Neutral": sentiment["neu"]
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
btc_df = pd.DataFrame(btc_sentiments)

# Reorder DataFrame columns
cols = ["Compound", "Positive", "Negative", "Neutral", "text"]
btc_df = btc_df[cols]

btc_df.head()
# Out:
#    Compound  Positive  Negative  Neutral  \
# 0    0.2023     0.124     0.107    0.769
# 1    0.0000     0.000     0.000    1.000
# 2    0.0000     0.000     0.000    1.000
# 3   -0.5106     0.103     0.168    0.730
# 4    0.1280     0.052     0.041    0.907
#
#                                                 text
# 0  Just when you thought the catastrophic Equifax...
# 1  After launching two cryptocurrency-oriented sm...
# 2  If youve been following cryptocurrency news fo...
# 3  Indias Supreme Court on Wednesday overturned c...
# 4  But its still unclear if you need to report th...

# %%
# Create the Bitcoin sentiment scores DataFrame
eth_sentiments = []

for article in eth_headlines["articles"]:
    try:
        sentiment = analyzer.polarity_scores(article["content"])
      
        eth_sentiments.append({
            "text": article["content"],
            "Compound": sentiment["compound"],
            "Positive": sentiment["pos"],
            "Negative": sentiment["neg"],
            "Neutral": sentiment["neu"]
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
eth_df = pd.DataFrame(eth_sentiments)

# Reorder DataFrame columns
cols = ["Compound", "Positive", "Negative", "Neutral", "text"]
eth_df = eth_df[cols]

eth_df.head()
# Out:
#    Compound  Positive  Negative  Neutral  \
# 0    0.0000     0.000     0.000    1.000
# 1    0.0000     0.000     0.000    1.000
# 2    0.3182     0.112     0.066    0.822
# 3    0.7184     0.130     0.000    0.870
# 4    0.4019     0.068     0.000    0.932
#
#                                                 text
# 0  If a player picks up an item in an online vide...
# 1  If youve been following cryptocurrency news fo...
# 2  When it comes to celebrities shilling shady in...
# 3  Skale Network is taking steps to help its cryp...
# 4  The South Korean National Assembly passed new ...

# %%
# Describe the Bitcoin Sentiment
btc_df.describe()
# Out:
#         Compound   Positive   Negative    Neutral
# count  19.000000  19.000000  19.000000  19.000000
# mean    0.285547   0.071632   0.031211   0.897211
# std     0.413528   0.042250   0.053201   0.068506
# min    -0.612400   0.000000   0.000000   0.730000
# 25%     0.064000   0.065500   0.000000   0.864500
# 50%     0.507000   0.068000   0.000000   0.932000
# 75%     0.507000   0.085500   0.046500   0.932000
# max     0.789300   0.137000   0.168000   1.000000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#         Compound   Positive   Negative    Neutral
# count  19.000000  19.000000  19.000000  19.000000
# mean    0.338805   0.074316   0.013263   0.912526
# std     0.337116   0.061652   0.027235   0.064576
# min    -0.458800   0.000000   0.000000   0.788000
# 25%     0.012900   0.022500   0.000000   0.876000
# 50%     0.421500   0.068000   0.000000   0.928000
# 75%     0.553200   0.112500   0.000000   0.938000
# max     0.859100   0.212000   0.083000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary
lemmatizer = WordNetLemmatizer() 
sw = stopwords.words('english')
sw.append("'s")
sw.append("n't")
sw.append('…')
sw.append("\`")
sw.append('``')
sw.append("''")
sw = set(sw)

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Create a list of the words
    words = word_tokenize(text)

    # Convert the words to lowercase
    regex = re.compile("[^a-zA-Z ]")
    
    # Remove the punctuation

    re_clean = regex.sub('', text)
    
    # Remove the stopwords
    words = word_tokenize(re_clean)
    
    # Lemmatize Words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
    
    output = [word.lower() for word in lem if word.lower() not in sw]
    
    return output

# %%
btc_df["tokens"] = btc_df.text.apply(tokenizer)
btc_df.head()
# Out:
#    Compound  Positive  Negative  Neutral  \
# 0    0.2023     0.124     0.107    0.769
# 1    0.0000     0.000     0.000    1.000
# 2    0.0000     0.000     0.000    1.000
# 3   -0.5106     0.103     0.168    0.730
# 4    0.1280     0.052     0.041    0.907
#
#                                                 text  \
# 0  Just when you thought the catastrophic Equifax...
# 1  After launching two cryptocurrency-oriented sm...
# 2  If youve been following cryptocurrency news fo...
# 3  Indias Supreme Court on Wednesday overturned c...
# 4  But its still unclear if you need to report th...
#
#                                               tokens
# 0  [thought, catastrophic, equifax, breach, wa, e...
# 1  [launching, two, cryptocurrencyoriented, smart...
# 2  [youve, following, cryptocurrency, news, past,...
# 3  [indias, supreme, court, wednesday, overturned...
# 4  [still, unclear, need, report, themimage, epic...

# %%
# Create a new tokens column for ethereum
eth_df["tokens"] = eth_df.text.apply(tokenizer)
eth_df.head()
# Out:
#    Compound  Positive  Negative  Neutral  \
# 0    0.0000     0.000     0.000    1.000
# 1    0.0000     0.000     0.000    1.000
# 2    0.3182     0.112     0.066    0.822
# 3    0.7184     0.130     0.000    0.870
# 4    0.4019     0.068     0.000    0.932
#
#                                                 text  \
# 0  If a player picks up an item in an online vide...
# 1  If youve been following cryptocurrency news fo...
# 2  When it comes to celebrities shilling shady in...
# 3  Skale Network is taking steps to help its cryp...
# 4  The South Korean National Assembly passed new ...
#
#                                               tokens
# 0  [player, pick, item, online, video, game, owns...
# 1  [youve, following, cryptocurrency, news, past,...
# 2  [come, celebrity, shilling, shady, initial, co...
# 3  [skale, network, taking, step, help, cryptocur...
# 4  [south, korean, national, assembly, passed, ne...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
btc_bigram_counts = ngrams(tokenizer(btc_df.text.str.cat()), n=2)
Counter(btc_bigram_counts).most_common(20)
# Out:
# [(('satoshi', 'nakaboto'), 22),
#  (('btc', 'every'), 12),
#  (('charsour', 'robot'), 11),
#  (('robot', 'colleague'), 11),
#  (('colleague', 'satoshi'), 11),
#  (('nakaboto', 'writes'), 11),
#  (('writes', 'bitcoin'), 11),
#  (('bitcoin', 'btc'), 11),
#  (('every', 'fucking'), 11),
#  (('fucking', 'daywelcome'), 11),
#  (('daywelcome', 'another'), 11),
#  (('another', 'edition'), 11),
#  (('edition', 'bitcoin'), 11),
#  (('bitcoin', 'today'), 11),
#  (('today', 'satoshi'), 11),
#  (('nakaboto', 'tell'), 11),
#  (('tell', 'whats'), 11),
#  (('whats', 'going'), 11),
#  (('going', 'bitcoin'), 11),
#  (('bitcoin', 'past'), 11)]

# %%
eth_bigram_counts = ngrams(tokenizer(eth_df.text.str.cat()), n=2)
Counter(eth_bigram_counts).most_common(20)
# Out:
# [(('new', 'technology'), 2),
#  (('indemand', 'skill'), 2),
#  (('list', 'blockchain'), 2),
#  (('satoshi', 'nakaboto'), 2),
#  (('player', 'pick'), 1),
#  (('pick', 'item'), 1),
#  (('item', 'online'), 1),
#  (('online', 'video'), 1),
#  (('video', 'game'), 1),
#  (('game', 'owns'), 1),
#  (('owns', 'item'), 1),
#  (('item', 'player'), 1),
#  (('player', 'company'), 1),
#  (('company', 'made'), 1),
#  (('made', 'gamein'), 1),
#  (('gamein', 'case'), 1),
#  (('case', 'answer'), 1),
#  (('answer', 'probably'), 1),
#  (('probably', 'closer'), 1),
#  (('closer', 'latter'), 1)]

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
btc_all_tokens = tokenizer(btc_df.text.str.cat())
token_count(btc_all_tokens, 10)
# Out:
# [('bitcoin', 35),
#  ('satoshi', 22),
#  ('nakaboto', 22),
#  ('past', 12),
#  ('btc', 12),
#  ('every', 12),
#  ('today', 12),
#  ('charsour', 11),
#  ('robot', 11),
#  ('colleague', 11)]

# %%
# Get the top 10 words for Ethereum
eth_all_tokens = tokenizer(eth_df.text.str.cat())
token_count(eth_all_tokens, 10)
# Out:
# [('new', 11),
#  ('blockchain', 7),
#  ('bitcoin', 7),
#  ('company', 5),
#  ('cryptocurrency', 4),
#  ('today', 4),
#  ('called', 4),
#  ('player', 3),
#  ('item', 3),
#  ('digital', 3)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
def wordcloud(text, title=""):
    df_cloud = WordCloud(width=500, colormap='RdYlBu').generate(text)
    plt.imshow(df_cloud)
    plt.axis("off")
    fontdict = {"fontsize": 48, "fontweight" : "bold"}
    plt.title(title, fontdict=fontdict)
    plt.show()

# %%
# Generate the Bitcoin word cloud
wordcloud(btc_df.text.str.cat(), title="Bitcoin Word Cloud")

# %%
# Generate the Ethereum word cloud
wordcloud(eth_df.text.str.cat(), title="Ethereum Word Cloud")

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
all_btc_text = btc_df.text.str.cat()
all_btc_text
# Out:
# "Just when you thought the catastrophic Equifax breach was entirely in the rearview, the Department of Justice this week charged four Chinese military hackers with the theft. That's 147.9 million people's Social Security numbers and other personal information … [+4002 chars]After launching two cryptocurrency-oriented smartphones, the HTC Exodus 1 and the Exodus 1s, the company is expanding the lineup with an entirely new device: a 5G router that can function as a full Bitcoin node.\xa0\r\nCalled the HTC Exodus 5G hub, the Android-bas… [+2230 chars]If youve been following cryptocurrency news for the past few months, theres one word that keeps coming back DeFi, also known as decentralized finance. As the name suggests, DeFi aims to bridge the gap between decentralized blockchains and financial services.\r… [+983 chars]Indias Supreme Court on Wednesday overturned\xa0central banks two-year-old ban on cryptocurrency trading in the country in what many said was a historic verdict.\r\nThe Reserve Bank of India had imposed a ban on cryptocurrency trading in April 2018 that barred ban… [+1336 chars]But its still unclear if you need to report them\r\nImage: Epic Games\r\nOn Wednesday, the IRS quietly changed a provision on its website that said transactions of virtual currency like Fortnites V-bucks were taxable and may have to be reported on tax returns, as… [+2532 chars]Image copyrightDutch policeImage caption\r\n Dutch police have warned companies to look out for padded envelopes with two stamps\r\nPolice are investigating a spate of letter-bomb attacks on companies across the Netherlands.\r\nFour letter bombs have been found in … [+2882 chars]The next Bitcoin Halving will take place on May 20th 2020. It will be the third time, that the block reward of the most known blockchain will be halved. As a consequence, miners will earn 50 percent less BTC for every generated block. Experts are expecting, t… [+922 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Machiavelli used to say: Money makes t… [+2973 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Stephen Hawking used to say: Lets get … [+3088 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Rousseau used to say: Success is just … [+2892 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Hegel used to say: Whip it, whip it, w… [+2889 chars]The South Korean National Assembly passed new legislation today that will provide a framework for the regulation and legalization of cryptocurrencies and crypto exchanges.\r\nIn a unanimous vote during a special session of the legislature convened amidst the co… [+2878 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Marie Curie used to say: Talk to a str… [+2973 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Stephen Hawking used to say: Fight the… [+3054 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, w ...

# %%
# Run the NER processor on all of the text
doc = nlp(all_btc_text)

# Add a title to the document
doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Just when you thought the catastrophic
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Equifax
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  breach was entirely in the rearview,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Department of Justice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  charged
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  military hackers with the theft. That's
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     147.9 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people's
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Social Security
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  numbers and other personal information … [+4002 chars]After launching
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  cryptocurrency-oriented smartphones, the HTC Exodus 1 and the Exodus 1s, the company is expanding the lineup with an entirely new device: a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# G router that can function as a full
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>Called the HTC Exodus 5G hub, the Android-bas… [+2230 chars]If youve been following cryptocurrency news for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the past few months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , theres one word that keeps coming back
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     DeFi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , also known as decentralized finance. As the name suggests,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     DeFi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# … [+983 chars]Indias
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Supreme Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  overturned central banks
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     two-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     The Reserve Bank of India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had imposed a ban on cryptocurrency trading in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     April 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>On
# <mark class="enti

# %%
# List all Entities
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Equifax ORG
# the Department of Justice ORG
# this week DATE
# four CARDINAL
# Chinese NORP
# 147.9 million CARDINAL
# Social Security ORG
# two CARDINAL
# 5 CARDINAL
# Bitcoin GPE
# the past few months DATE
# DeFi ORG
# DeFi PERSON
# Supreme Court ORG
# Wednesday DATE
# two-year-old DATE
# The Reserve Bank of India ORG
# April 2018 DATE
# Wednesday DATE
# IRS ORG
# Fortnites ORG
# Dutch NORP
# two CARDINAL
# Netherlands GPE
# Four CARDINAL
# Bitcoin Halving ORG
# May 20th 2020 DATE
# third ORDINAL
# 50 percent PERCENT
# BTC ORG
# Satoshi Nakaboto PERSON
# Bitcoin BTC ORG
# every fucking day DATE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Satoshi Nakaboto PERSON
# Bitcoin BTC ORG
# every fucking day DATE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Stephen Hawking PERSON
# Satoshi Nakaboto PERSON
# Bitcoin BTC ORG
# every fucking day DATE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Rousseau PERSON
# Success ORG
# Satoshi Nakaboto PERSON
# Bitcoin BTC ORG
# every fucking day DATE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Hegel PERSON
# South Korean National Assembly ORG
# today DATE
# Satoshi Nakaboto PERSON
# Bitcoin BTC ORG
# every fucking day DATE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Marie Curie PERSON
# Satoshi Nakaboto PERSON
# Bitcoin BTC ORG
# every fucking day DATE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Stephen Hawking PERSON
# Satoshi Nakaboto PERSON
# Bitcoin BTC ORG
# every fucking day DATE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Baudriallard PERSON
# Success ORG
# Satoshi Nakaboto PERSON
# Bitcoin BTC ORG
# every fucking day DATE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Plato PERSON
# Success ORG
# Satoshi Nakaboto PERSON
# Bitcoin BTC ORG
# every fucking day DATE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Baudriallard PERSON
# Satoshi Nakaboto PERSON
# Bitcoin BTC ORG
# every fucking day DATE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Hannah Arendt PERSON
# Satoshi Nakaboto PERSON
# Bitcoin BTC ORG
# every fucking day DATE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Nightingale ORG

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
all_eth_text = eth.text.str.cat()
all_eth_text
# Out:
# 'If a player picks up an item in an online video game, who owns that item? The player, or the company that made the game?\r\nIn most cases, the answer is probably closer to the latter. The item may be in the players digital inventory – but the company can take i… [+2713 chars]If youve been following cryptocurrency news for the past few months, theres one word that keeps coming back DeFi, also known as decentralized finance. As the name suggests, DeFi aims to bridge the gap between decentralized blockchains and financial services.\r… [+983 chars]When it comes to celebrities shilling shady initial coin offerings for money, the Securities and Exchange Commission is out for justice.\xa0\r\nActor Steven Seagal found himself on deadly ground on Thursday following an SEC charge that, back in 2018, he failed to … [+2035 chars]Skale Network is taking steps to help its cryptocurrency tokens stand up to regulatory scrutiny in an effort to encourage wide adoption for its blockchain-based technology.\r\nSkale Network, overseen by the N.O.D.E. Foundation, will be the first project to laun… [+2511 chars]In the murky world of crypto and blockchain, taking disputes to a traditional court would either land both the plaintiff and the defendant in jail or confuse the court to the point of total befuddlement. You can just imagine the scenario:\r\nWhat is a DAO?\r\nIts… [+3338 chars]The South Korean National Assembly passed new legislation today that will provide a framework for the regulation and legalization of cryptocurrencies and crypto exchanges.\r\nIn a unanimous vote during a special session of the legislature convened amidst the co… [+2878 chars]To say a lot happened this past week would be is an understatement. It seems that 2020 has no intention of slowing down based on all the recent happenings of the blockchain, DApps &amp; DLT landscapes. Lets take a deep breath and calmly try to go through it a… [+5316 chars]Last June, at a swanky, strobe-lit event in Washington, DC, Brendan Blumer, the 33-year-old CEO of a blockchain company called Block.one, unveiled a new product with Steve Jobs-like theatrics: a social network called Voice. A year earlier, Blumers company had… [+3666 chars]I just bought some US Dollars today. I do that many days. But the dollars I bought today are crypto assets, like Bitcoin and Ethereum. These US Dollar assets are called USDC and they are issued by an industry consortium called Centre, led by Circle and our po… [+2120 chars]The world of storage is changing rapidly. We have exciting new technologies such as Intel DC Persistent Memory, along with new applications such as machine learning and blockchain which place new requirements on storage systems. Researchers are working on new… [+7451 chars]Today, were excited to launch a new version of Terminal - the easiest way to build, deploy, and host websites &amp; apps on IPFS. From local development to global deployment, Terminal provides one seamless workflow with everything you need to build fast, mode… [+5610 chars]February\r\n26, 2020\r\n7 min read\r\nThis story originally appeared on PC MagCryptocurrency is digital currency, or a “digital representation of value,” as the IRS puts it. You can’t see it, hold it in your hand, or put it in your wallet. It’s been in use for over… [+7653 chars]Last month, LinkedIn published a list of the most in-demand skills for the new year, with blockchain leading the top-ten list. In 2019, blockchain didnt make the list at all. Blockchain also ranked as the most in-demand skills in the United States, the United… [+5960 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Baudriallard used to say: Lets whip up… [+2613 chars]About This Page\r\nThis is a Techmeme archive page.\r\nIt shows how the site appeared at 10:15\xa0AM\xa0ET, February\xa013,\xa02020.\r\nThe  ...

# %%
# Run the NER processor on all of the text
eth_doc = nlp(all_eth_text)

# Add a title to the document
eth_doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(eth_doc, style='ent', jupyter=True)
# Out:
# <h2 style="margin: 0">Ethereum NER</h2>
#
# </br>In most cases, the answer is probably closer to the latter. The item may be in the players digital inventory – but the company can take i… [+2713 chars]If youve been following cryptocurrency news for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the past few months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , theres one word that keeps coming back
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     DeFi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , also known as decentralized finance. As the name suggests,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     DeFi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# … [+983 chars]When it comes to celebrities shilling shady initial coin offerings for money,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Securities and Exchange Commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Actor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Steven Seagal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  found himself on deadly ground on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  following an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     SEC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  charge that, back in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , he failed to … [
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     +2035 chars]Skale Network
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Skale Network
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , overseen by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the N.O.D.E. Foundation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , will be the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </br>What is a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     DAO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Its… [+3338 chars]The South Korean National Assembly passed new legislation
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>In a unanimous vote during a special session of the legislature convened amidst the co… [+2878 chars]To say a lot happened
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     this past week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  would be is an understatement. It seems that
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  has no intention of slowing down based on all the recent happenings of the blockchain,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     DApps &amp;amp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ; DLT landscapes. Lets take a deep breath and calmly try to go through it a… [+5316 chars]Last
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">

# %%
# List all Entities
for ent in eth_doc.ents:
    print(ent.text, ent.label_)
# Out:
# the past few months DATE
# DeFi ORG
# DeFi PERSON
# the Securities and Exchange Commission ORG
# Steven Seagal PERSON
# Thursday DATE
# SEC ORG
# 2018 DATE
# +2035 chars]Skale Network ORG
# Skale Network ORG
# the N.O.D.E. Foundation ORG
# first ORDINAL
# DAO ORG
# today DATE
# this past week DATE
# 2020 DATE
# DApps &amp ORG
# June DATE
# Washington, DC GPE
# Brendan Blumer PERSON
# Block.one ORG
# Steve Jobs-like PERSON
# Voice ORG
# A year earlier DATE
# US GPE
# today DATE
# many days DATE
# today DATE
# Bitcoin GPE
# Ethereum GPE
# US GPE
# USDC ORG
# Centre ORG
# Circle ORG
# Intel DC Persistent Memory ORG
# Terminal ORG
# IPFS ORG
# Terminal ORG
# one CARDINAL
# 26, 2020
#  DATE
# 7 CARDINAL
# MagCryptocurrency ORG
# IRS ORG
# LinkedIn ORG
# the new year DATE
# ten CARDINAL
# 2019 DATE
# the United States GPE
# United ORG
# Satoshi Nakaboto PERSON
# Bitcoin BTC ORG
# every fucking day DATE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Baudriallard PERSON
# 10:15 CARDINAL
# February DATE
# 13 CARDINAL
# 2020 CARDINAL
# Fatburger ORG
# AFP ORG
# Getty Images
#  PERSON
# Lubin PERSON
# Ethereum PERSON
# Founder PERSON
# Consensys
# Getty Images PERSON
# the last few years DATE
# Luno PERSON
# Ripple's XRP ORG
# third ORDINAL
# XRP ORG
# Luno ORG
# Thursday DATE
# Decentraland ORG
